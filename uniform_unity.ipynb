# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import uniform_unity

# %%
ndim, nsamples = 3, 10000
xi = uniform_unity(size = (nsamples,ndim))

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d')
ax.scatter(xi[:,0], xi[:,1], xi[:,2], marker='.', s=1)
ax.view_init(15, 120)
